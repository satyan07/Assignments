# %%
import cv2
import numpy as np
from matplotlib import pyplot as plot
im = cv2.imread('./Image1.jpg')
#BY DEFAULT , CV2 TAKES THE COLOR CODE IN BGR , SO WE HAVE TO CONVERT 
#IT INTO RGB
im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
print(im.shape)
plot.imshow(im)
plot.show()
# Out:
# (683, 1024, 3)

# %%
#Flatten the image
all_pixels = im.reshape((-1,3))
print(all_pixels.shape)
# Out:
# (699392, 3)

# %%
from sklearn.cluster import KMeans
dominant_colors = 6
km = KMeans( n_clusters = dominant_colors)
km.fit(all_pixels)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=6, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
centers = km.cluster_centers_

# %%
centers = np.array(centers, dtype = 'uint8')
print(centers)
# Out:
# [[ 69 144 221]
#  [ 49  90  60]
#  [129 181 234]
#  [ 20  25  11]
#  [151 144  84]
#  [216 228 237]]

# %%
i = 1
plot.figure(0,figsize = (8,2))

colors =[]
for each_col in centers:
    plot.subplot(1,6,i)
    plot.axis("off")
    i+=1
    
    colors.append(each_col)
    
    a = np.zeros((100,100,3), dtype= "uint8")
    a[:,:,:] = each_col
    plot.imshow(a)
plot.show()

# %%
plot.subplot?

# %%
new_img = np.zeros((699392,3),dtype = 'uint8')
print(new_img.shape)
colors
km.labels_
# Out:
# (699392, 3)
# array([2, 2, 2, ..., 3, 3, 3], dtype=int32)

# %%
for ix in range(new_img.shape[0]):
    new_img[ix] = colors[kn.labels_[ix]]

new_img = new_img.reshape((683, 1024, 3))
plot.imshow(new_img)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-33dfd3c47b67> in <module>
#       1 for ix in range(new_img.shape[0]):
# ----> 2     new_img[ix] = colors[kn.labels_[ix]]
#       3
#       4 new_img = new_img.reshape((683, 1024, 3))
#       5 plot.imshow(new_img)
#
# NameError: name 'kn' is not defined
